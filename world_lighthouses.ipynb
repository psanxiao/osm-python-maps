# %%
import overpass
import geopandas
import matplotlib.pyplot as plt

# %%
data = "./data/galician-lighthouses.geojson"
map_data = geopandas.read_file(data)

# %%
map_data.head()
# Out:
#               id            @id    man_made                           name  \
# 0  node/13391742  node/13391742  lighthouse                        Streiti
# 1  node/17022899  node/17022899  lighthouse       Tacking Point Lighthouse
# 2  node/17898241  node/17898241  lighthouse                     Wick South
# 3  node/21270143  node/21270143  lighthouse                   Macduff Pier
# 4  node/25141160  node/25141160  lighthouse  Pāvilostas dienvidu mola bāka
#
#   seamark:light:1:character seamark:light:1:colour seamark:light:1:group  \
# 0                        Fl                  green                     3
# 1                      None                   None                  None
# 2                        Fl                  green                  None
# 3                        Fl                  green                     2
# 4                      None                   None                  None
#
# ...

# %%
ax = map_data.plot(color="yellow", figsize=(60, 60))
ax.set_facecolor('black')
plt.savefig('/Users/psanxiao/Downloads/faros.png')
